# %%
#python syntax
print("Hello World")
#defining a string to a variable
A="ziaur"
print(A)
#defining an integer
x = 10
y = "Hi Afroz!"
print(x,y)
#Arithmetic operations 
a = 15
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
#sting manipulation
txt = "Hi, welcome"
x = txt.capitalize()
print (x)
x = txt.find("welcome")
print(x)
x = txt.index("Hi")
print(x)
x = txt.upper()
print(x)
#conditional statements
a = 6
b = 20
if b > a:
  print("b is greater than a")
else:
    print("a is greater than b")



#defining a list
x= [4, 7, 1, 8, 10]
#defining a list
y= [6, 'ziaur', 'welcome', 6.0, True]
#accessing elements from lists
print(x[0])
print(x[0:2])
print(y[1])
print(x[-1])
print(y[:3])
#updating a list
y[1] = "zia"
print(x)
#indexing method 
print(x.index(1))
#sorting a list
print(x.count(5))
print(x.sort())
print(x.sort(reverse=True))
#appending an element to list
x.append(5)
print(x)
#removing element from a list
x.remove(7)
print(x)
print(x.pop(3))
print(x)
#extending a list
x.extend([4,5])
print(x)
y.insert(4, [0, 9])
print("\n")
print(x)
print(y)



#Dictionarys
dict = {'name': 'Ziaur', 'age': 20}
#Accessing the specific key from the dictionary
print(dict.get('name'))
print(dict.get('address', 'Not Found'))

#Returns a list of all the keys and values in the dictionary
dict = {'name': 'Ziaur', 'age': 20}
print(dict.keys())
print(dict.values())

#return a list of all key-value pairs in the dictionary
dict = {'name': 'Manasa', 'age': 19}
print(dict.items())

#Updating the list  key-value pairs to a dictionary 
dict = {'name': 'Hinata', 'age': 19}
dict.update({'age': 30, 'address': '1224 Street'})
print(dict)

#Removing the list key-value pair from a dictionary
dict = {'name': 'Jyothi', 'age': 18, 'address': '2405 Street'}
removed_value = dict.pop('address')
print(removed_value)
print(dict)

#Returns the last key-value pair added to the dictionary
dict = {'name': 'Afroz', 'age': 21, 'address': '07 Street'}
removed_pair = dict.popitem()
print(removed_pair)
print(dict)



#defining a tuple
mytuple = ("app", "website", "chrome")
#printing the tuple
print(mytuple)
#defining the length of the tuple
print(len(mytuple))
#Create Tuple With One Item
thistuple = ("apple",)
print(type(thistuple))
##combination of data types
tuple1 = ("abc", 34, True, 40, "male")
#type()
mytuple = ("lollipop", "biscuit", "chocolate")
print(type(mytuple))
#The tuple() Constructor
thistuple = tuple(("pyaar", "afroz", "ziaur"))
print(thistuple)
#accessing tuples
tupleA = ("biscuit", "chocolate", "lollipop")
print(tupleA[1])
#Negative Indexing
Atuple = ("apple", "banana", "cherry")
print(Atuple[-1])
#Range of Indexes
thistuple = ("ziaur","afroz","anees","jitendra","chinchu","manasa","gayathri")
print(thistuple[2:5])
#Range of Negative Indexes
thistuple = ("ziaur","afroz","anees","jitendra","chinchu","manasa","gayathri")
print(thistuple[-4:-1])
#add items
thistuple = ("ziaur","afroz","anees")
y = list(thistuple)
y.append("sujitha")
thistuple = tuple(y)
#add tuple to tuple 
y = ("chinchu",)
thistuple += y
print(thistuple)
#unpack tuples
fruits = ("papaya", "water melon", "mango")
(green, yellow, red) = fruits
print(green)
print(yellow)
print(red)
#loop through a tuple 
thistuple = ("papaya", "water melaon", "mango")
for x in thistuple:
  print(x)
#joining two tuples
tuple1 = ("A", "B" , "C")
tuple2 = (5, 6, 7)
tuple3 = tuple1 + tuple2
print(tuple3)
#joining multiple tuples 
fruits = ("papaya", "water melaon", "mango")
mytuple = fruits * 2
print(mytuple)
# Out:
# Hello World
# ziaur
# 10 Hi Afroz!
# 35
# -5
# 300
# 0.75
# 0
# 15
# 332525673007965087890625
# Hi, welcome
# 4
# 0
# HI, WELCOME
# b is greater than a
# 4
# [4, 7]
# ziaur
# 10
# [6, 'ziaur', 'welcome']
# [4, 7, 1, 8, 10]
# 2
# 0
# None
# None
# [10, 8, 7, 4, 1, 5]
# [10, 8, 4, 1, 5]
# 1
# [10, 8, 4, 5]
# [10, 8, 4, 5, 4, 5]
#
#
# [10, 8, 4, 5, 4, 5]
# [6, 'zia', 'welcome', 6.0, [0, 9], True]
# Ziaur
# Not Found
# dict_keys(['name', 'age'])
# dict_values(['Ziaur', 20])
# dict_items([('name', 'Manasa'), ('age', 19)])
# {'name': 'Hinata', 'age': 30, 'address': '1224 Street'}
# 2405 Street
# {'name': 'Jyothi', 'age': 18}
# ('address', '07 Street')
# {'name': 'Afroz', 'age': 21}
# ('app', 'website', 'chrome')
# 3
# <class 'tuple'>
# <class 'tuple'>
# ('pyaar', 'afroz', 'ziaur')
# chocolate
# cherry
# ('anees', 'jitendra', 'chinchu')
# ('jitendra', 'chinchu', 'manasa')
# ('ziaur', 'afroz', 'anees', 'sujitha', 'chinchu')
# papaya
# water melon
# mango
# papaya
# water melaon
# mango
# ('A', 'B', 'C', 5, 6, 7)
# ('papaya', 'water melaon', 'mango', 'papaya', 'water melaon', 'mango')
